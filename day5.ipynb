# %%
import pandas as pd

a = [10,20,30,40,50]

dic = {'a':10,'b':20,'c':30,'d':40}

s = pd.Series(dic)

print(s)
print(pd.Series(a))
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# s.size
# s.dtype
# s.is_unique
# s.index

print(s)
s.head(1)

s.tail(1)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# d    40
# dtype: int64

# %%
import numpy as np 

arr = np.arange(100,1000)

s = pd.Series(arr)

s.head(10)

s.tail(10)
# Out:
# 890    990
# 891    991
# 892    992
# 893    993
# 894    994
# 895    995
# 896    996
# 897    997
# 898    998
# 899    999
# dtype: int64

# %% [markdown]
# # **Indexing and Slicing**

# %%
s.loc[2]
# Out:
# np.int64(102)

# %%
s.iloc[1]
# Out:
# np.int64(101)

# %%
s = pd.Series([10,20,30,40,50], index=['a','b','c','d','e'])

# print(s)

# s.iloc[-1]

# print(s.iloc[[1,2,3]])

# s.loc[['a','b','c','d','e']]

# s.loc['a']

# print(s.iloc[1:4])

# %% [markdown]
# **Editing a series**

# %%
# s[0] = 100

# print(s)

# s.iloc[5]

# s[14] = 25

# s['a':'c'] = [200,300,400]

s['d':'e'] = 25

print(s)

s
# Out:
# a    10
# b    20
# c    30
# d    25
# e    25
# dtype: int64
# a    10
# b    20
# c    30
# d    25
# e    25
# dtype: int64

# %% [markdown]
# **NULL VALUES HANDLING**

# %%
s.isnull()
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# dtype: bool

# %%
arr = np.array([1,7,np.nan,2,4,np.nan,6,np.nan,4,7,2,8,1,1,3,4])

s = pd.Series(arr)

# print(s.isnull().sum)

# s.isnull().sum()
# print(s.notnull())

# print(s.hasnans)

# %% [markdown]
# **UNIQUE VALUES**

# %%
arr = np.array([1,7,np.nan,2,4,np.nan,6,np.nan,4,7,4,4,2,8,3,1,1,3,4])


s = pd.Series(arr)

s.unique()

s.nunique()

s.is_unique
# Out:
# False

# %% [markdown]
# # **PYTHON INBUILD FUNCTIONS**

# %%
print(min(s))
print(max(s))
print(len(s))
print(type(s))
# print(dir(s))

print(sorted(s))
# Out:
# 1.0
# 8.0
# 19
# <class 'pandas.Series'>
# [1.0, 1.0, 1.0, 7.0, nan, 2.0, 4.0, nan, 2.0, 3.0, 6.0, nan, 3.0, 4.0, 4.0, 4.0, 4.0, 7.0, 8.0]

# %% [markdown]
# **TYPE CONVERSION**

# %%
arr = np.array([10,40,70,20,80,90,36,43,69,91,66,18,74,49])

s = pd.Series(arr)

# print(s.astype(int))

# print(s.astype(float))

# print(s.astype(bool))

# print(s.astype(str))

# list(s)

# tuple(s)

# dict(s)

set(s)
# Out:
# {10, 18, 20, 36, 40, 43, 49, 66, 69, 70, 74, 80, 90, 91}
