# %%
import pandas as pd

a = [10,20,30,40,50]

dic = {'a':10,'b':20,'c':30,'d':40}

s = pd.Series(dic)

print(s)
print(pd.Series(a))
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# s.size
# s.dtype
# s.is_unique
# s.index

print(s)
s.head(1)

s.tail(1)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# d    40
# dtype: int64

# %%
import numpy as np 

arr = np.arange(100,1000)

s = pd.Series(arr)

s.head(10)

s.tail(10)
# Out:
# 890    990
# 891    991
# 892    992
# 893    993
# 894    994
# 895    995
# 896    996
# 897    997
# 898    998
# 899    999
# dtype: int64

# %% [markdown]
# # **Mathematical Functions**

# %%
s.count()  # 900 not null values
# Out:
# np.int64(900)

# %%
arr = np.array([1,7,np.nan,2,4,np.nan,6,np.nan,4,7,2,8,1,1,3,4])

# print(arr)

s = pd.Series(arr)

# print(s)

u = s.size
v = s.count()

# print(u-v)

s.sum()
# Out:
# np.float64(50.0)

# %%
s.product()
# Out:
# np.float64(1806336.0)

# %%
s.mean()
# Out:
# np.float64(3.8461538461538463)

# %%
s.mode()
# Out:
# 0    1.0
# 1    4.0
# dtype: float64

# %%
s.var()
# Out:
# np.float64(6.141025641025641)

# %%
s.std()
# Out:
# np.float64(2.4781092875467863)

# %%
s.max()
# Out:
# np.float64(8.0)

# %%
s.min()
# Out:
# np.float64(1.0)

# %%
s.describe()
# Out:
# count    13.000000
# mean      3.846154
# std       2.478109
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       6.000000
# max       8.000000
# dtype: float64
