# %%
import pandas as pd

a = [10,20,30,40,50]

dic = {'a':10,'b':20,'c':30,'d':40}

s = pd.Series(dic)

print(s)
print(pd.Series(a))
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# s.size
# s.dtype
# s.is_unique
# s.index

print(s)
s.head(1)

s.tail(1)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# d    40
# dtype: int64

# %%
import numpy as np 

arr = np.arange(100,1000)

s = pd.Series(arr)

s.head(10)

s.tail(10)
# Out:
# 890    990
# 891    991
# 892    992
# 893    993
# 894    994
# 895    995
# 896    996
# 897    997
# 898    998
# 899    999
# dtype: int64

# %% [markdown]
# # **Membership Operator**

# %%
# print(0 in s)

print(91 in s)

# print(s.isin([10]))

# print(s.isin([10,20,30,40]))
# Out:
# True

# %% [markdown]
# # **LOOPING OVER A SERIES**

# %%
# for i in s:
#     print(i)

# for i in s.index:
#     print(i)

for i,v in s.items():
    print(i,v)
# Out:
# 0 100
# 1 101
# 2 102
# 3 103
# 4 104
# 5 105
# 6 106
# 7 107
# 8 108
# 9 109
# 10 110
# 11 111
# 12 112
# 13 113
# 14 114
# 15 115
# 16 116
# 17 117
# 18 118
# 19 119
# 20 120
# 21 121
# 22 122
# 23 123
# 24 124
# 25 125
# 26 126
# 27 127
# 28 128
# 29 129
# 30 130
# 31 131
# 32 132
# 33 133
# 34 134
# 35 135
# 36 136
# 37 137
# 38 138
# 39 139
# 40 140
# 41 141
# 42 142
# 43 143
# 44 144
# 45 145
# 46 146
# 47 147
# 48 148
# 49 149
# 50 150
# 51 151
# 52 152
# 53 153
# 54 154
# 55 155
# 56 156
# 57 157
# 58 158
# 59 159
# 60 160
# 61 161
# 62 162
# 63 163
# 64 164
# 65 165
# 66 166
# 67 167
# 68 168
# 69 169
# 70 170
# 71 171
# 72 172
# 73 173
# 74 174
# 75 175
# 76 176
# 77 177
# 78 178
# 79 179
# 80 180
# 81 181
# 82 182
# 83 183
# 84 184
# 85 185
# 86 186
# 87 187
# 88 188
# 89 189
# 90 190
# 91 191
# 92 192
# 93 193
# 94 194
# 95 195
# 96 196
# 97 197
# 98 198
# 99 199
# 100 200
# 101 201
# 102 202
# 103 203
# 104 204
# 105 205
# 106 206
# 107 207
# 108 208
# 109 209
# 110 210
# ...

# %%
def square(a):
    return a*a

s.apply(square)

# print(s.apply(square))
# Out:
# 0       10000
# 1       10201
# 2       10404
# 3       10609
# 4       10816
#         ...
# 895    990025
# 896    992016
# 897    994009
# 898    996004
# 899    998001
# Length: 900, dtype: int64

# %% [markdown]
# # **Arthematic Operator**

# %%
s+5
s-5
s*5
s/5
s%5
s**5
# Out:
# 0          10000000000
# 1          10510100501
# 2          11040808032
# 3          11592740743
# 4          12166529024
#             ...
# 895    975248753121875
# 896    980159361278976
# 897    985089730404757
# 898    990039920079968
# 899    995009990004999
# Length: 900, dtype: int64
