# %% [markdown]
# # **Series and Attributes** #

# %%
import pandas as pd

a = [10,20,30,40,50]

dic = {'a':10,'b':20,'c':30,'d':40}

s = pd.Series(dic)

print(s)
print(pd.Series(a))
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# s.size
# s.dtype
# s.is_unique
# s.index

print(s)
s.head(1)

s.tail(1)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# d    40
# dtype: int64

# %%
import numpy as np 

arr = np.arange(100,1000)

s = pd.Series(arr)

s.head(10)

s.tail(10)
# Out:
# 890    990
# 891    991
# 892    992
# 893    993
# 894    994
# 895    995
# 896    996
# 897    997
# 898    998
# 899    999
# dtype: int64
